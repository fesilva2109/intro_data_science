# %% [markdown]
# <a href="https://colab.research.google.com/github/fesilva2109/intro_data_science/blob/main/aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
sns.displot(tmdb["revenue"])
plt.title("Revenue Distribution")
plt.xlabel("Revenue")
plt.ylabel("Frequency")
plt.show()

# %%
# prompt: gráfico de distribuição do orçamento dos filmes (budget)

import matplotlib.pyplot as plt
sns.displot(tmdb['budget'])
plt.title('Budget Distribution')
plt.xlabel('Budget')
plt.ylabel('Frequency')
plt.show()

# %%
tmdb.info()
tmdb.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
com_faturamento = tmdb.query("revenue > 0")
sns.displot(com_faturamento["revenue"])
plt.title("Revenue Distribution")
plt.xlabel("Revenue")
plt.ylabel("Frequency")
plt.show()

# %%
tmdb.query("budget == 0")
# Out:
#       budget                                             genres  \
# 265        0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...
# 321        0                     [{"id": 35, "name": "Comedy"}]
# 359        0  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 406        0  [{"id": 18, "name": "Drama"}, {"id": 16, "name...
# 409        0  [{"id": 18, "name": "Drama"}, {"id": 10402, "n...
# ...      ...                                                ...
# 4795       0                      [{"id": 18, "name": "Drama"}]
# 4797       0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 265                                                 NaN   10588
# 321                                                 NaN   77953
# ...

# %%
tmdb.query("popularity >20").sort_values("popularity", ascending=False)
# Out:
#          budget                                             genres  \
# 546    74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
# 95    165000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 788    58000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 94    170000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 127   150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 590    70000000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 2260          0  [{"id": 18, "name": "Drama"}, {"id": 9648, "na...
# 1628   30000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 2595   15000000                      [{"id": 18, "name": "Drama"}]
# 1940   25000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
#
#                                                homepage      id  \
# 546                        http://www.minionsmovie.com/  211672
# ...

# %%
sns.displot(tmdb["popularity"])
plt.title("Popularity Distribution")
plt.xlabel("Popularity")
plt.ylabel("Frequency")
plt.show()

# %%
#budget (orçamento) => quantitativa continua
#nota do movielens => 0.5,1,2 => não tem 2.5
#quantidade de votos => 1,2,3,4 => não existe 2.5 votos
#revenue (faturamento) => quantitativa continua
#popularity (popularidade) => quantitativa discreta
#original_language (linguagem original) => qualitativa nominal

# %%
tmdb["original_language"].unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
contagem_lingua = tmdb["original_language"].value_counts().to_frame().reset_index()
contagem_lingua.columns = ["original_language","total"]
contagem_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(x="original_language", y="total", data=contagem_lingua)
plt.title("Language Distribution")
plt.xlabel("Language")
plt.ylabel("Total")
plt.show()

# %%
contagem_lingua.plot(kind="pie",y="total",labels = contagem_lingua["original_language"])
plt.title("Language Distribution")
# Out:
# Text(0.5, 1.0, 'Language Distribution')

# %%
total_lingua = tmdb["original_language"].value_counts()
total_geral = total_lingua.sum()
total_ingles = total_lingua.loc["en"]
total_resto = total_geral- total_ingles
print(total_geral,total_ingles, total_resto)
# Out:
# 4803 4505 298

# %%
sns.barplot(x=["ingles","Outras Línguas"], y=[total_ingles,total_resto])
plt.title("Language Distribution")
plt.xlabel("Language")
plt.ylabel("Total")
plt.show()

# %%
dados = {
    "lingua" : ["Inglês","Outras Línguas"],
    "total" : [total_ingles,total_resto]
}
dados = pd.DataFrame(dados)
dados
# Out:
#            lingua  total
# 0          Inglês   4505
# 1  Outras Línguas    298

# %%
dados.plot(kind="pie",y="total",labels = dados["lingua"])
plt.title("Language Distribution")
# Out:
# Text(0.5, 1.0, 'Language Distribution')

# %%
sns.barplot(data = dados, x = "lingua", y = "total")
plt.title("Language Distribution")
plt.xlabel("Language")
# Out:
# Text(0.5, 0, 'Language')

# %%
total_outros_filmes = tmdb.query("original_language != 'en'")["original_language"].value_counts()
total_outros_filmes.head()
# Out:
# original_language
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# Name: count, dtype: int64

# %%
sns.countplot(data = tmdb.query("original_language != 'en'"),x="original_language")
plt.title("Language Distribution")
plt.xlabel("Language")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
sns.countplot(data = tmdb.query("original_language != 'en'"), order = total_outros_filmes.index,x="original_language")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2cf0dc2a2ac5> in <cell line: 7>()
#       5 tmdb = pd.read_csv("tmdb_5000_movies.csv")
#       6 tmdb.head()
# ----> 7 sns.countplot(data = tmdb.query("original_language != 'en'"), order = total_outros_filmes.index,x="original_language")
#
# NameError: name 'total_outros_filmes' is not defined
